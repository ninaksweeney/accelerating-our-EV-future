# %% [markdown]
# ![kbb.png](attachment:kbb.png)

# %% [markdown]
# ![corr_heatmap.png](attachment:corr_heatmap.png)

# %% [markdown]
# ![difference_in_means.png](attachment:difference_in_means.png)
